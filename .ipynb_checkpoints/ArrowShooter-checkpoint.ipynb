# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split

# %%
# CURATE DATA

data_path = 'data/20k_data.csv'
label_path = 'data/20k_labels.csv'

data = pd.read_csv(data_path, low_memory=False)
label = pd.read_csv(label_path, low_memory=False)

headers = ['x', 'y', 'z']
num_objs = (data.shape[1] - 3) // 2

dists = []
heights = []
for i in range(num_objs):
    dists.append('dist_' + str(i))
    heights.append('height_' + str(i))
    headers.append('dist_' + str(i))
    headers.append('height_' + str(i))
    
data.columns = headers
data = data.replace(to_replace='None', value=0).astype('float')

# %%
# CURATE ONLY MAX HEIGHT DATA

h_col = data[heights].idxmax(axis=1)
h_ind = [data.columns.get_loc(c) for c in h_col]

data_mh_list = [data.iloc[i, [0, 1, 2, col-1, col]].tolist() for i in range(len(h_ind))]
mh_headers = ['x', 'y', 'z', 'dist', 'height']
mh = pd.DataFrame(data_mh_list, columns=mh_headers)

# %%
# EXPERIMENT ON ONLY MAX HEIGHT DATA



X_train, X_test, y_train, y_test = train_test_split(data, label, test_size=0.33, random_state=42)
# Out:
#           x     y     z       dist    height
# 0       1.0  -9.0  18.0   9.000000 -6.881834
# 1      -7.0   9.0   8.0   8.602325  1.686251
# 2      -5.0   1.0 -24.0  14.142136  1.820938
# 3      20.0   3.0  18.0   9.219544 -1.510026
# 4      19.0   7.0 -16.0  14.212670 -0.088837
# 5      -7.0  -6.0 -21.0  12.649111 -5.657927
# 6      12.0   8.0 -20.0  11.180340  0.819405
# 7     -19.0   3.0 -23.0  19.209373 -1.847937
# 8     -19.0  -4.0   4.0  11.180340 -2.433476
# 9      -9.0   8.0 -25.0  15.811388  4.727461
# 10     24.0  -2.0 -19.0  22.203603 -2.391782
# 11    -25.0  -7.0  -9.0  16.763055 -3.881671
# 12     16.0  -4.0  10.0   8.602325 -2.718815
# 13      0.0   8.0  13.0   0.000000  0.000000
# 14    -22.0  -8.0  15.0   8.602325 -3.354845
# 15     -9.0   3.0   7.0   7.071068 -1.328895
# 16      6.0   6.0  11.0   9.433981  1.332572
# 17     25.0  -8.0 -19.0  22.203603 -6.887482
# 18     17.0   5.0  14.0   8.485281 -0.926696
# 19      2.0   3.0  11.0   9.055385  1.201873
# 20     -2.0  -9.0  25.0   9.055385 -5.995502
# 21     -6.0  -5.0  -5.0   0.000000  0.000000
# 22    -20.0   8.0  -1.0   1.000000 -0.734514
# 23    -19.0   5.0 -20.0  17.691806  0.462295
# 24     20.0   8.0  15.0  10.000000  0.405930
# 25      7.0   1.0  -4.0   0.000000  0.000000
# 26      6.0   8.0   0.0   0.000000  0.000000
# 27     11.0  -7.0  11.0   8.485281 -4.273526
# 28     -4.0   3.0 -13.0   3.000000 -1.761427
# 29     -6.0   1.0 -23.0  13.341664  0.279167
# ...     ...   ...   ...        ...       ...
# 19970  -5.0  -8.0 -22.0  12.165525 -7.365378
# 19971 -18.0   7.0   9.0  10.770330  2.181341
# 19972 -16.0 -10.0 -18.0  14.142136 -6.907764
# 19973 -10.0   0.0   3.0   7.615773 -2.421609
# 19974  16.0  -8.0  16.0   8.485281 -6.295643
# 19975  -2.0   5.0  12.0   8.062258  1.433441
# 19976  -4.0   7.0  13.0   9.486833  1.564769
# 19977  16.0   7.0   6.0   9.486833 -0.211685
# 19978 -16.0   1.0   8.0  10.770330 -2.908544
# 19979  -2.0   4.0 -22.0  12.041595  0.784493
# 19980  -3.0  -8.0 -20.0  10.049876 -7.573546
# 19981 -17.0   2.0  18.0   8.485281 -2.013025
# 19982 -24.0  -3.0  -6.0  13.601471 -2.071783
# 19983   2.0 -10.0  23.0   9.000000 -7.140703
# 19984  19.0   9.0  24.0   8.602325 -0.784507
# 19985  -9.0  -3.0  20.0  10.295630 -3.559331
# 19986   0.0   6.0  -3.0   0.000000  0.000000
# 19987  -6.0  -4.0 -22.0  12.369317 -4.189411
# 19988  25.0  -4.0  20.0   8.485281 -0.511943
# 19989  -6.0  -7.0   2.0   0.000000  0.000000
# 19990  19.0   9.0 -18.0  16.278821  2.347975
# 19991  -6.0   8.0  17.0   8.246211 -0.074796
# 19992 -21.0  -3.0   1.0   2.000000 -1.210703
# 19993  16.0  -4.0   0.0   0.000000  0.000000
# 19994  21.0   6.0   0.0  18.000000 -1.145543
# 19995 -22.0  -2.0   8.0   8.544004 -1.911923
# 19996 -10.0   6.0  -5.0   1.414214 -2.461940
# 19997  -3.0   4.0 -17.0   7.071068  1.755489
# 19998  -9.0  -8.0  17.0   9.433981 -4.131851
# 19999  11.0   6.0   2.0   7.280110  1.917201
#
# [20000 rows x 5 columns]
#        pitch         yaw    f
# 0         27   -3.179830  1.0
# 1        -38   41.185925  1.0
# 2        -68  168.231711  0.6
# 3         -8  -48.012788  1.0
# 4        -17 -130.100908  1.0
# 5         15  161.565051  1.0
# 6        -20 -149.036243  1.0
# 7         -8  140.440332  1.0
# 8        -74   78.111342  0.6
# 9        -19  160.201124  1.0
# 10        -7 -128.367485  0.7
# 11         0    0.000000  0.0
# 12         4  -57.994617  0.6
# 13       -29   -0.000000  1.0
# 14       -68   55.713123  0.6
# 15       -10   52.125016  1.0
# 16       -22  -28.610460  1.0
# 17       -71 -127.234834  0.7
# 18       -13  -50.527540  1.0
# 19       -12  -10.304846  1.0
# 20        18    4.573921  1.0
# 21         0    0.000000  0.0
# 22       -22   92.862405  1.0
# 23       -12  136.468801  1.0
# 24       -19  -53.130102  1.0
# 25         1 -119.744881  1.0
# 26       -49  -90.000000  1.0
# 27         0    0.000000  0.0
# 28       -72  162.897271  0.5
# 29       -10  165.379126  0.7
# ...      ...         ...  ...
# 19970     18  167.195734  1.0
# 19971    -19   63.434949  1.0
# 19972      0    0.000000  0.0
# 19973      6   73.300756  1.0
# 19974    -63  -45.000000  0.5
# 19975    -47    9.462322  0.4
# 19976    -70   17.102729  0.5
# 19977    -21  -69.443955  1.0
# 19978     -2   63.434949  1.0
# 19979      0    0.000000  0.0
# 19980     21  171.469234  1.0
# 19981     -6   43.363423  1.0
# 19982      0    0.000000  0.0
# 19983     22   -4.969741  1.0
# 19984    -19  -38.367485  1.0
# 19985      7   24.227745  1.0
# 19986    -58 -180.000000  1.0
# 19987      9  164.744881  1.0
# 19988    -13  -51.340192  0.6
# 19989    -53   71.565051  0.2
# 19990    -21 -133.451842  1.0
# 19991    -23   19.440035  1.0
# 19992      0    0.000000  0.0
# 19993    -58  -90.000000  0.4
# 19994    -16  -90.000000  1.0
# 19995      0    0.000000  0.0
# 19996    -24  116.565051  1.0
# 19997      0    0.000000  0.0
# 19998     -6   27.897271  0.4
# 19999    -24  -79.695154  1.0
#
# [20000 rows x 3 columns]
